# %%
import configparser
import boto3
import json
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

# %%
DWH_DB_USER       = config.get('CLUSTER','DB_USER')
DWH_DB_PASSWORD   = config.get('CLUSTER','DB_PASSWORD')
DWH_ENDPOINT      = config.get('CLUSTER','HOST')
DWH_PORT          = config.get('CLUSTER','DB_PORT')
DWH_DB            = config.get('CLUSTER','DB_NAME')
DWH_DB            = config.get('CLUSTER','DB_NAME')
ARN               = config.get("IAM_ROLE", "ARN")

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://dwhuser:Passw0rd@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 'Connected: dwhuser@dwh'

# %% [markdown]
# # Practice Importing All The Tables

# %%
# Import all the SQL queries
from sql_queries import *

# %%
# Drop all the tables
for drop_query in drop_table_queries:
    print(drop_query)
    # %sql $drop_query
# Out:
# DROP TABLE  IF EXISTS staging_events;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS staging_songs;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS songplay;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS users;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS songs;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS artists;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# DROP TABLE  IF EXISTS time;
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.

# %%
for table_create_query in create_table_queries:
    # print(table_create_query)
    # %sql $table_create_query
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.

# %% [markdown]
# ``` sql
# %%sql
#
# SELECT DISTINCT(tablename) FROM PG_TABLE_DEF WHERE schemaname = 'public';
# ```

# %%
# %%sql
# TRUNCATE staging_songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
## Now to input the JSON into a table from S3 into Redshift

s3_insert_query = """
COPY staging_songs FROM 's3://udacity-dend/song_data' 
iam_role '{}'
format as json 'auto';""".format(ARN)
# s3_insert_query = """
# COPY staging_songs FROM 's3://udacity-dend/song_data/A/B/Q/TRABQTA128F148D048.json' 
# iam_role '{}'
# format as json 'auto';""".format(ARN)
print(s3_insert_query)
# Out:
# COPY staging_songs FROM 's3://udacity-dend/song_data'
# iam_role 'arn:aws:iam::245289978277:role/dwhRole'
# format as json 'auto';

# %%
# %sql $s3_insert_query
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
# %%sql
# SELECT COUNT(*) FROM staging_songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(14896,)]

# %% [markdown]
# ## What about ndjson?

# %%
# %%sql
# TRUNCATE staging_events;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
s3_insert_query = """
COPY staging_events FROM 's3://udacity-dend/log_data' 
iam_role '{}'
format as json 'auto ignorecase';""".format(ARN)

# s3_insert_query = """
# COPY staging_events FROM 's3://udacity-dend/log_data/2018/11/2018-11-05-events.json' 
# iam_role '{}'
# format as json 'auto ignorecase';""".format(ARN)
print(s3_insert_query)
# Out:
# COPY staging_events FROM 's3://udacity-dend/log_data'
# iam_role 'arn:aws:iam::245289978277:role/dwhRole'
# format as json 'auto ignorecase';

# %%
# %sql $s3_insert_query
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
# %%sql
# select COUNT(*) from staging_events
# LIMIT 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(8056,)]

# %%
# %%sql
# SELECT * FROM stl_load_errors
# LIMIT 10;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 0 rows affected.
# []

# %% [markdown]
# ## Transformation Time
#
# * Let's first take staging_songs table and get the artists working as an example
#
# **Example ETL SQL Query**
# ``` sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
# ```

# %% [markdown]
# ## ETL artists table
#
# I am having an issue inserting distinct artist_id from the staging_songs table into the artists table. I am really confused how I am getting a different number for the number for duplicate artist_id's and distinct artist_id's. But before I show my thinking process I want to articulate my understanding of previous questions here on Udacity.
#
# [Knowledge - Udacity](https://knowledge.udacity.com/questions/440181)
#
# From this question about using UPSERT on redshift I learned that UPSERT is not supported on REDSHIFT and to reference the [AWS Redshift docs](https://docs.aws.amazon.com/redshift/latest/dg/t_updating-inserting-using-staging-tables-.htm)
# The AWS Redshift documentation talks about updating and deleting stuff rather than trying to have a UNIQUE constraint
# Therefore is the best thing to do is insert form the staging_songs table all the columns then go through and delete any columns that are not distonct/unique?
#
# [Knowledge - Udacity](https://knowledge.udacity.com/questions/474021)
#
# This answer says to use DISTINCT which I already was using
#
# [Knowledge - Udacity](https://knowledge.udacity.com/questions/775809)
#
# This answer also says to use DISTINCT
# Use Group By, which I tried an had an issue (see below)
#
# ## Process I followed to get the confusing numbers
#
# ``` sql
# SELECT COUNT(*) FROM staging_songs;
# ```
#
# I get a count of 14896 back. Now I get how many distinct artist_id's are in the staging_songs table
#
# ``` sql
# SELECT COUNT(DISTINCT artist_id) FROM staging_songs;
# ```
#
# I get a count of 9553 back. Therefore I can not calculate the number of duplicate artist_id's there are.
#
# 14896 rows in staging_songs - 9553 distinct artist_id's = 5343 duplicate artist_id's in the staging_songs table.
#
# Now I insert from the staging_songs table into the artists table using distinct on artist_id, when I try and use
#
# ```sql
# INSERT INTO artists (artist_id, name, location, latitude, longitude)
#     SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs;
# ```
#
# I tried using GROUP BY like the third question I referenced above but I get the error, "column "staging_songs.artist_name" must appear in the GROUP BY clause or be used in an aggregate function". Is this a case where I can use a subquery?
#
# Next I get the number of rows in the artists table.
#
# ```sql
# SELECT COUNT(*) FROM artists;
# ```
#
# Returns 10025 results, which does not look right to me, I expect 9553 rows. Now I check for distinct artists....
#
# ```sql
# SELECT COUNT(DISTINCT artist_id) FROM artists;
# ```
#
# Returns a COUNT of 9553. This matches the number of distinct artist_id I had in the staging_songs table.
#
# ``` sql
# SELECT COUNT(*) from artists;
# ```
#
# Returns a COUNT of 10025, then I do a query to get the number of duplicate artist_id in artists
#
# ``` sql
# SELECT artist_id,
#  COUNT(artist_id) AS NumOccurrences
# FROM staging_songs
# GROUP BY artist_id
# HAVING ( COUNT(artist_id) > 1 )
# ORDER BY NumOccurrences desc
# ```
#
# Source: [Finding Duplicates with SQL](https://www.petefreitag.com/item/169.cfm)
#
# And I get 3349 results with the NumOccurrences counting up to numbers as high as 9.
#
# How is it possible that I can insert what should be distinct values and have (10025-9553)=472, 472 duplicates but when I count the number of duplicate entries being over 3000? Let's check if these NumOccurrences actually matches up. I write a query to see if I actually get 9 instances with the artist_id.
#
# ``` sql
# SELECT * FROM staging_songs
# WHERE artist_id = 'ARYPTWE1187FB49D64';
# ```
#
# Got 9 results back?
#
# How can I have 3349 duplicate artist_id's in the artists table, a total of 10025 total results and 9553 distinct artist_id values.
#
# ## Summary
#
# Do I even need to worry about distinct artist_id's in the artists table?
# Where in my logic am I wrong when calculating the distinct and duplicate artist_id's in the staging_artists and artists table?
# Is it a good idea to dump everything from staging_songs into artists then delete duplicates?
# Is my SQL query to find duplicates correct?
# Do I need to go back and review some core SQL knowledge, if so what, or am I missing something nuanced?

# %%
print(artist_table_insert)
# Out:
# INSERT INTO artists (artist_id, name, location, latitude, longitude)
#     SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs;

# %%
# %%sql
# TRUNCATE TABLE ARTISTS;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
# %%sql
# SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs
#     GROUP BY artist_id;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# (psycopg2.ProgrammingError) column "staging_songs.artist_name" must appear in the GROUP BY clause or be used in an aggregate function
#  [SQL: 'SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude\n    FROM staging_songs\n    GROUP BY artist_id;']

# %%
# %%sql
# SELECT COUNT(*) FROM staging_songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(14896,)]

# %%
second_artist_table_insert = """
INSERT INTO artists (artist_id, name, location, latitude, longitude)
    SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude
    FROM staging_songs
    WHERE artist_id NOT IN (SELECT DISTINCT artist_id FROM artists);
"""

# %%
# %sql $second_artist_table_insert
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 10025 rows affected.
# []

# %%
# %%sql
# SELECT COUNT(*) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(10025,)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(artist_id)) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(9553,)]

# %%
# %%sql
# SELECT COUNT(*) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(10025,)]

# %%
# %%sql
# SELECT DISTINCT(artist_id) from artists
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('AR00B1I1187FB433EB',),
#  ('AR016P51187B98E398',),
#  ('AR01SCU1187B9A693C',),
#  ('AR02IU11187FB513F2',),
#  ('AR02LMQ1187B992AC9',)]

# %%
# %%sql
# SELECT DISTINCT(artist_id), artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs
#     WHERE artist_id NOT IN (SELECT DISTINCT artist_id FROM artists);
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 0 rows affected.
# []

# %%
# %%sql
# SELECT artist_id,
#  COUNT(artist_id) AS NumOccurrences
# FROM staging_songs
# GROUP BY artist_id
# HAVING ( COUNT(artist_id) > 1 )
# ORDER BY NumOccurrences desc
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('ARYPTWE1187FB49D64', 9),
#  ('ARUPWVD1187FB4DA36', 9),
#  ('ARLHO5Z1187FB4C861', 8),
#  ('ARH6W4X1187B99274F', 8),
#  ('ARD2NDU1187B99B615', 8)]

# %%
# %%sql
# SELECT * FROM staging_songs
# WHERE artist_id = 'ARYPTWE1187FB49D64';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 9 rows affected.
# [('SOAOMUV12AB018B851', None, 'Quino-Phec', 'Polygon Window', None, 0, 283.48036, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOHTUFU12AB017DC46', None, 'Carn Marth', 'Aphex Twin', None, 1996, 153.36444, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOLHRZE12B0B8066D9', None, 'Phlange Phace', 'Aphex Twin', None, 1992, 322.35057, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOZDTEK12A8151D34F', None, 'Come On You Slags', 'Aphex Twin', None, 1995, 344.65914, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOZGFSN12A6D4FE1FC', None, 'Acrid Avid Jam Shred', 'Aphex Twin', None, 1995, 459.28444, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOEXSNO12A6D4FA33A', None, 'Kladfvgbung Mischk', 'Aphex Twin', None, 2001, 126.64118, 'ARYPTWE1187FB49D64', None, ''),
#  ('SODVIBY12AB0186823', None, 'Audax Powder', 'Polygon Window', None, 0, 280.52853, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOLPAOX12A6D4F9894', None, 'Jynweythek', 'Aphex Twin', None, 2001, 143.882, 'ARYPTWE1187FB49D64', None, ''),
#  ('SOZDGSX12A8C139AA7', None, 'Tha', 'Aphex Twin', None, 1992, 547.13424, 'ARYPTWE1187FB49D64', None, '')]

# %%
# %%sql
# SELECT COUNT(DISTINCT(artist_id)) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(9553,)]

# %%
# %%sql
# SELECT DISTINCT (artist_id) , artist_name
#     FROM staging_songs
#     GROUP BY ts;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# (psycopg2.ProgrammingError) column "ts" does not exist in staging_songs
#  [SQL: 'SELECT DISTINCT (artist_id) , artist_name\n    FROM staging_songs\n    GROUP BY ts;']

# %%
# %%sql
# SELECT DISTINCT(artist_id) as p_key, artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs
#     GROUP BY p_key, artist_name, artist_location, artist_latitude, artist_longitude
#     HAVING ( COUNT(p_key) > 1 );
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 3122 rows affected.
# [('ARTC1LV1187B9A4858', 'The Bonzo Dog Band', "Goldsmith's College, Lewisham, Lo", 51.4536, -0.01802),
#  ('AR2L9A61187B9ADDBC', 'Tangerine Dream', 'Berlin, Germany', 52.51607, 13.37698),
#  ('ARBVASN1187B9890CB', 'Lucky Boys Confusion', 'Chicago, IL', None, None),
#  ('ARS927Z1187B9ACA29', 'Robert Plant', 'Birmingham, England', None, None),
#  ('ARTMSN91187FB3A3B7', 'Annihilator', '', None, None),
#  ('ARYKCQI1187FB3B18F', 'Tesla', '', None, None),
#  ('ARDTIOA1187B99E779', 'Cloud Cult', 'Minneapolis, MN', 44.97903, -93.26493),
#  ('AR190KO1187B9905EC', 'Sick Puppies', 'Sydney, Australia', 34.05349, -118.24532),
#  ('ARA36TP1187B99AEB5', 'Jan & Dean', '', None, None),
#  ('AR8MI421187FB36E98', 'Tony Christie', '', None, None),
#  ('ARPKAUL1187B9A8F82', 'Dr. Hook', 'New Jersey', 40.14323, -74.72671),
#  ('AR4ASIL1187FB46020', '30Y', '', None, None),
#  ('ARCGQQ11187B994F5D', 'Sentidos Opuestos', '', None, None),
#  ('ARMWCF81187B98F7E0', 'Nitzer Ebb', 'Chelmsford, Essex, England', 51.73569, 0.47791),
#  ('ARNMKA51187FB4D40D', 'Uzeb', 'ANN ARBOR, Michigan', 42.32807, -83.7336),
#  ('ARSRFOY1187B9917DA', 'Otis Taylor', 'Chicago, IL', 41.88415, -87.63241),
#  ('AR6OOVR1187B98DA0E', 'Flat Duo Jets', '', None, None),
#  ('ARBQ12H1187B9A9223', 'Hablando en Plata', '', None, None),
#  ('ARV1L7J1187B98DD57', 'The Gits', 'California - SF', 37.77916, -122.42005),
#  ('ARFZNLS1187B9B10D8', 'Brian Bromberg', '', None, None),
#  ('ARG6A591187B9B757A', 'The Chameleons', 'Middleton, England', 52.50208, -0.76588),
#  ('ARNH6Q11187FB40FDD', 'Jeru The Damaja', 'Brooklyn, NY', 40.65507, -73.94888),
#  ('ARVEJGQ12420783D8A', 'Magida El Roumi', '', None, None),
#  ('ARPOBPN1187B9ADA45', 'George Winston', 'Michigan', None, None),
#  ('ARVLRUA1187FB57C69', 'PsyCraft', '', None, None),
#  ('ARSZP6T1187B989F0A', 'Ringworm', 'Cleveland, OH', 41.50471, -81.69074),
#  ('ARUTDLO1187FB4A79A', 'Julian Fane', '', None, None),
#  ('ARIRJWO1187B9BA43F', 'Fact', '', None, None),
#  ('ARLQ1IL1187FB3C77A', 'Bob Welch', 'Los Angeles, CA', 34.05349, -118.24532),
#  ('ARHKW8K1187FB4C9A2', 'Orbit', '', None, None),
#  ('ARNP6X21187B98A630', 'Kasse Mady Diabate', '', None, None),
#  ('ARE03EE1187B9BA249', 'Johnny Shines', 'Frayser, TN', 35.22052, -90.01479),
#  ('ARLQV2F1187B99929B', 'Les Reines Prochaines', '', None, None),
#  ('AR2665Z1187FB56AB9', 'Commodores', 'Tuskegee, AL', None, None),
#  ('ARQ4BDR1187B99C5AE', 'Highspire', '', None, None),
#  ('ARJ8GM51187FB5557B', 'Boney M.', 'Germany', 51.16418, 10.45415),
#  ('ARM7EDF1187B9B3FA1', "Guns N' Roses", '', None, None),
#  ('ARYI5981187FB4A0CD', 'Houston Calls', 'Rockaway, NJ', 40.91188, -74.52772),
#  ('ARVLHS71187FB5B9C9', 'Pig Destroyer', 'Washington, DC', None, None),
#  ('AR0Z2F41187B9B2E1F', 'Terminal Choice', '', None, None),
#  ('ARBFQAE1187FB3E957', 'Stephanie Mills', 'Brooklyn, NY', 40.65507, -73.94888),
#  ('AR0F2WH1187B99C65A', 'The Kissaway Trail', 'Odense, Denmark', 55.39617, 10.39079),
#  ('ARCIGKY1187FB4FAC7', 'Lucybell', '', None, None),
#  ('ARBR2RC1187B9ABE99', 'Dan Barta', '', None, None),
#  ('AR2DP8Z1187FB3C4D7', 'Horse The Band', 'Los Angeles, CA', 34.05349, -118.24532),
#  ('AREZHIK1187B9AEB46', 'Terrorvision', '', None, None),
#  ('ARVUI9A1187FB39AAA', 'Anathema', 'Liverpool, England', None, None),
#  ('AR8V1WA1187B9AD9E9', 'The White Stripes', 'Nashville / Los Angeles', 42.33168, -83.04792),
#  ('ARFMT4W1187FB42FA8', 'Alison Krauss', 'Decatur, IL', None, None),
#  ('ARVHQNN1187B9B9FA3', 'Cat Stevens', 'London, England', None, None),
#  ('ARVB3M81187B98908F', 'Thyrfing', '', None, None),
#  ('ARNWVN41187B9A51BB', 'Scanners', 'London/Stroud', 51.50632, -0.12714),
#  ('ARRH52A1187B9ABAF0', 'Otis Rush', 'Philadelphia, MS', 32.7716, -89.11774),
#  ('ARP32X81187B99EBF5', 'Vanessa Bell Armstrong', 'Detroit, MI', 42.33168, -83.04792),
#  ('ARCA3NH1187B9AE11B', 'The Flower Kings', '', None, None),
#  ('ARORX9K1187FB3DC3F', 'White Lion', 'Minnetonka Minnesota USA', 44.93944, -93.46787),
#  ('ARGE26T1187B9891C8', 'Paul Winter', 'Altoona, PA', 40.50719, -78.3989),
#  ('ARDAF601187FB4CD05', 'Ashanti', 'Glen Cove, NY', None, None),
#  ('ARGJRWL122988FD0C8', 'The Glorious Unseen', '', None, None),
#  ('ARQUHF41187B9A2E9E', 'Sidney Polak', '', None, None),
#  ('ARITDIH1187B9B18CD', 'Tiktak', 'Helsinki', 60.17116, 24.93258),
#  ('ARQQ3PM1187FB41517', 'Catherine Feeny', 'California - LA', None, None),
#  ('ARQ6OS81187B998B73', 'Kid Dynamite', 'Philadelphia, PA', None, None),
#  ('ARPZ87F1187FB4D072', 'The Adverts', '', None, None),
#  ('ARJWPFY12086C12521', 'Title Tracks', 'Washington DC', None, None),
#  ('ARS99FV1187FB501FE', 'The Potbelleez', '', None, None),
#  ('ARCIDMF11E2835DBF2', 'Torsten Goods', 'GERMANY', None, None),
#  ('AR1PN1B1187FB36561', 'The Rumble Strips', 'Devon, England', 50.72805, -3.71925),
#  ('ARWI0HO1187FB5311E', 'Van Der Graaf Generator', '', None, None),
#  ('ARFBTBY1187FB517BF', 'Groundation', 'Sonoma, CA. USA', 38.29187, -122.45724),
#  ('AR46LG01187B98DB5D', 'The Detroit Cobras', '', None, None),
#  ('ARIZOHT1187B9A0CF8', 'K-Rino', 'Texas', 31.1689, -100.07715),
#  ('ARHFGKH1187B9A88D2', 'The Durutti Column', 'Manchester, England', 53.4796, -2.24881),
#  ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', None, None),
#  ('ARU78KE1187FB37E2F', 'Jake Shimabukuro', '', None, None),
#  ('ARZZXT51187FB4627E', 'Julie Driscoll_ Brian Auger & The Trinity', '', None, None),
#  ('AR8B1WY1187FB38366', 'Rakim', 'Long Island, NY', None, None),
#  ('ARZQ1KI1187FB4E578', 'Emilie Simon', '', None, None),
#  ('ARK7YKK1187B990D04', 'Theatre Of Tragedy', 'Norway (Stavanger) ', 58.97083, 5.73079),
#  ('ARYBFTU1187B9AE5D0', 'The Donnas', '', None, None),
#  ('ARU4CDK1187B9B259A', 'Andre Hazes', '', None, None),
#  ('AR0BQ871187FB43ED0', 'Gazpacho', 'NORWAY', 64.55653, 12.66538),
#  ('ARH5FJJ1187FB3F787', 'Alanis Morissette', 'Ottawa, Ontario, Canada', None, None),
#  ('AR5Z97E1187FB36169', 'Tego Calderon', '', None, None),
#  ('ARZQMTK1187FB4611A', 'Donavon Frankenreiter', 'Downey, CA', None, None),
#  ('ARK9JE31187FB36C28', 'Solitude Aeturnus', '', None, None),
#  ('AR5EH4F1187B98FC65', 'Berlin Symphony Orchestra', '', None, None),
#  ('ARCJJDC11F4C84860F', 'Sir Charles Jones', '', None, None),
#  ('AR8IDZK1187FB363F2', 'Jonezetta', 'Clinton, MS', 32.33765, -90.32943),
#  ('ARA24CR1187B99EEC6', 'Alucidnation', '', None, None),
#  ('ARYR2F11187B9976FA', 'AM', 'Tulsa, OK', 36.15398, -95.99277),
#  ('ARJB9TE1187FB3A9F8', 'The Edgar Broughton Band', '', None, None),
#  ('ARMX1AT1187FB3C326', 'Sezen Aksu', 'Turkey', 38.95774, 35.4317),
#  ('AR7H9EH1187B990F91', 'Tru', 'New York City, New York', 40.71455, -74.00712),
#  ('AR8XRCY1187B9A2BF7', 'The Kovenant', '', None, None),
#  ('AR3NHIA1187B9AC99B', 'My Life With The Thrill Kill Kult', 'LOS ANGELES via CHICAGO', 23.73606, -103.99279),
#  ('ARGWNT41187FB463F1', 'Matt Pond PA', 'Philadelphia, PA', None, None),
#  ('ARNXHP01187FB585FE', 'Skream', '', None, None),
#  ('AR8SQ9J1187FB3BADE', 'The Buff Medways', '', None, None),
#  ('ARS8O1D1187FB462D4', 'Lale Andersen', '', None, None),
#  ('ARVA5B71187B9A0FCD', 'Incognito', 'Colorado', None, None),
#  ('ARMSL551187FB3F4B0', "K's Choice", '', None, None),
#  ('ART9IB3119B8669227', 'Markus Krunegård', '', None, None),
#  ('ARHT48W1187B9ACEBA', 'Cerys Matthews', 'Cardiff, Wales', 51.48126, -3.18067),
#  ('ARKL75U1187FB5B8B6', 'BoDeans', 'Waukesha WI', 43.01437, -88.23546),
#  ('AROUKFV1187FB3CF2B', 'Sound Team', 'Austin, TX', 30.2676, -97.74298),
#  ('ARS5WKC1187B9AC7D1', 'Jim White', 'Maine', 45.26232, -69.01249),
#  ('ARWDEEB11E2835E73C', 'Faces', 'London, England', 51.50632, -0.12714),
#  ('ARPK4HR1187B9A289D', 'Tito El Bambino', '', None, None),
#  ('ARJ97ZM1187B9AD147', 'Within Temptation', 'The Netherlands', None, None),
#  ('ARIMZQZ1187B9AD541', 'Thrice', 'Orange, CA', None, None),
#  ('AR7ELF11187FB5444F', 'FM Static', 'Canada', 56.95468, -98.30897),
#  ('ARW70HR1187B9A358C', 'Aleks Syntek', 'Merida, Mexico', None, None),
#  ('ARRWVPI1187FB4615A', 'The Hurt Process', 'Brighton, England', 50.82821, -0.13449),
#  ('ARIWKUS1187FB55354', 'Coheed and Cambria', 'New York, NY', None, None),
#  ('AR0VZWC1187B99BA57', 'The Berzerker', 'Melbourne, Australia', -37.81753, 144.96715),
#  ('AREME651187B9A839D', 'The Earlies', '', None, None),
#  ('ARZPDAD1187B98D940', 'Fattburger', '', None, None),
#  ('ARJNXF41187FB3E0AC', 'Platero Y Tu', '', None, None),
#  ('AR2KOSS1187B9A8237', 'Classic Case', 'Chapel Hill, NC', 35.91463, -79.05661),
#  ('ARICWIL1187B9A869B', 'Canibus', 'Philly, PA', 39.95227, -75.16237),
#  ...]

# %%
# %%sql
# SELECT COUNT(DISTINCT(artist_id)) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(9553,)]

# %% [markdown]
# ## ETL songs table
#
# ``` sql
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# ```

# %%
# %%sql
# INSERT INTO songs (song_id, title, artist_id, year, duration)
# SELECT song_id, title, a.artist_id, year, duration
# FROM staging_songs s
# JOIN artists a     ON (s.artist_name=a.name);
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# []

# %%
# %%sql
# SELECT COUNT(*) FROM songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(1,)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(song_id)) FROM songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(1,)]

# %% [markdown]
# ## Transaction songs AND artists table
#
# ``` sql
# BEGIN TRANSACTION
#    DECLARE @DataID int;
#    INSERT INTO DataTable (Column1 ...) VALUES (....);
#    SELECT @DataID = scope_identity();
#    INSERT INTO LinkTable VALUES (@ObjectID, @DataID);
# COMMIT
# ```
#
# [SQL Server: Is it possible to insert into two tables at the same time? - Stack Overflow](https://stackoverflow.com/questions/175066/sql-server-is-it-possible-to-insert-into-two-tables-at-the-same-time)
#
#
# ``` sql
# INSERT INTO artists (artist_id, name, location, latitude, longitude)
#     SELECT artist_id, artist_name, artist_location, artist_latitude, artist_longitude
#     FROM staging_songs;
# INSERT INTO songs (song_id, title, artist_id, year, duration)
#     SELECT song_id, title, artist_id, year, duration
#     FROM staging_songs;
# ```

# %%
# %%sql
# SELECT COUNT(*) from artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(1,)]

# %% [markdown]
# ## How to convert a string to a TIMESTAMP or DATE
#
# * [DATEADD function - Amazon Redshift](https://docs.aws.amazon.com/redshift/latest/dg/r_DATEADD_function.html)
# * [How to convert epoch to datetime redshift? - Stack Overflow](https://stackoverflow.com/questions/39815425/how-to-convert-epoch-to-datetime-redshift)

# %%
# %%sql
# SELECT date_add('ms',CAST(ts as BIGINT),'1970-01-01')
# FROM staging_events LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000),),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000),),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000),),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000),),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000),)]

# %% [markdown]
# ## Practice getting events into the time table
#
# **Reminder Query for Syntax**
#
# ``` sql
# INSERT INTO dimDate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD')::integer) AS date_key,
#        date(payment_date)                                           AS date,
#        EXTRACT(year FROM payment_date)                              AS year,
#        EXTRACT(quarter FROM payment_date)                           AS quarter,
#        EXTRACT(month FROM payment_date)                             AS month,
#        EXTRACT(day FROM payment_date)                               AS day,
#        EXTRACT(week FROM payment_date)                              AS week,
#        CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6, 7) THEN true ELSE false END AS is_weekend
# FROM payment;
# ```

# %%
# %%sql
# SELECT 12;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(12,)]

# %%
# %%sql
# SELECT CASE WHEN 5 IN (5, 6) THEN true ELSE false END;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(True,)]

# %%
# %%sql
# SELECT CASE WHEN 2 IN (5, 6) THEN true ELSE false END;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(False,)]

# %%
# %%sql
# SELECT
#   date_add('ms',CAST(ts as BIGINT),'1970-01-01') as staged_date,
#   EXTRACT(WEEKDAY FROM staged_date)
# FROM staging_events
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), 1),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), 1),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), 1),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), 1),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), 1)]

# %%
# %%sql
# SELECT
#   date_add('ms',CAST(ts as BIGINT),'1970-01-01') as staged_date,
#   CASE WHEN EXTRACT(WEEKDAY FROM staged_date) IN (6,7) THEN true ELSE false END
# FROM staging_events
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), False),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), False),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), False),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), False),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), False)]

# %%
# %%sql
# SELECT date_add('ms',CAST(ts as BIGINT),'1970-01-01') as staged_date,
#     EXTRACT(hour FROM staged_date),
#     EXTRACT(day FROM staged_date),
#     EXTRACT(month FROM staged_date),
#     EXTRACT(year FROM staged_date),
#     CASE WHEN EXTRACT(WEEKDAY FROM staged_date) IN (6,7) THEN true ELSE false END
# FROM staging_events
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), 0, 5, 11, 2018, False),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), 1, 5, 11, 2018, False),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), 1, 5, 11, 2018, False),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), 1, 5, 11, 2018, False),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), 1, 5, 11, 2018, False)]

# %%
# %%sql
# INSERT INTO time (start_time, hour, day, month, year, weekday)
# SELECT date_add('ms',CAST(ts as BIGINT),'1970-01-01') as staged_date,
#     EXTRACT(hour FROM staged_date),
#     EXTRACT(day FROM staged_date),
#     EXTRACT(month FROM staged_date),
#     EXTRACT(year FROM staged_date),
#     CASE WHEN EXTRACT(WEEKDAY FROM staged_date) IN (6,7) THEN true ELSE false END
# FROM staging_events;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 408 rows affected.
# []

# %%
# %%sql
# SELECT COUNT(*) FROM time
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(408,)]

# %% [markdown]
# ## Practice getting events into the users table

# %%
# %%sql
# SELECT DISTINCT(userId), firstName, lastName, gender, level
#     FROM staging_events
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('69', 'Anabelle', 'Simpson', 'F', 'free'),
#  ('44', 'Aleena', 'Kirby', 'F', 'paid'),
#  ('52', 'Theodore', 'Smith', 'M', 'free'),
#  ('94', 'Noah', 'Chavez', 'M', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free')]

# %%
# %%sql
# SELECT CAST(userId as INT), firstName, lastName, gender, level
#     FROM staging_events
#     WHERE userId != ' '
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid'),
#  (44, 'Aleena', 'Kirby', 'F', 'paid')]

# %% [markdown]
# ## Unique is not enforced on AMAZON Redshift
#
# * [Defining table constraints - Amazon Redshift](https://docs.aws.amazon.com/redshift/latest/dg/t_Defining_constraints.html)
#
# ## Thinking
#
# Since we need to update the level we should be doing an UPDATE if the INSERT fails

# %%
# %%sql
# SELECT COUNT(*) FROM staging_events
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(408,)]

# %%
# %%sql
# SELECT DISTINCT(userId) as user_tmp, CAST(user_tmp as INT) as user_tmp_1
#     FROM staging_events
#     WHERE userId != ' '
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('69', 69), ('44', 44), ('52', 52), ('94', 94), ('32', 32)]

# %%
# %%sql
# SELECT DISTINCT(userId), firstName, lastName, gender, level FROM staging_events
# WHERE userId != ' '
# ORDER BY
#     ts ASC
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('69', 'Anabelle', 'Simpson', 'F', 'free'),
#  ('44', 'Aleena', 'Kirby', 'F', 'paid'),
#  ('52', 'Theodore', 'Smith', 'M', 'free'),
#  ('94', 'Noah', 'Chavez', 'M', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free')]

# %% [markdown]
# ## Other Failed Tries for the users table to make sure they are unique
#
# ``` sql
# %%sql
# MERGE INTO users USING staging_events ON (users.user_id = CAST(staging_events.userId as INT))
# WHEN MATCHED
#     update users
#         SET
#             users.first_name = staging_events.firstName
#             users.last_name  = staging_events.lastName
#             users.gender     = staging_events.gender
#             users.level      = staging_events.level
#         WHERE user_id=44
# THEN INSERT
#     INSERT INTO users (user_id, first_name, last_name, gender, level)
#     SELECT CAST(userId as INT), firstName, lastName, gender, level
#         FROM staging_events;
# ```
#
# ``` sql
# %%sql
# INSERT INTO users (user_id, first_name, last_name, gender, level)
# SELECT CAST(userId as INT), firstName, lastName, gender, level
#     FROM staging_events
#     WHERE userId != ' '
#     ORDER BY
#         ts ASC;
# ```
#
# ``` sql
# %%sql
# SELECT CASE WHEN
#     EXISTS(SELECT 1 from users where user_id=44)
# THEN
#     'update'
# ELSE
#     'insert'
# END;
# ```
#
# ``` sql
# %%sql
# SELECT CASE WHEN
#     EXISTS(SELECT 1 from users where user_id=44)
# THEN
#     update users
#         SET
#             first_name = firstName
#             last_name  = lastName
#             gender     = gender
#             level      = level
#         WHERE user_id=44
# ELSE
#     INSERT INTO users (user_id, first_name, last_name, gender, level)
#     SELECT CAST(userId as INT), firstName, lastName, gender, level
#         FROM staging_events
# END;
# ```

# %%
# %%sql
# SELECT COUNT(*) FROM users;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(401,)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(user_id)) FROM users;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(29,)]

# %% [markdown]
# ## Troubleshooting users table transofmration
#
# Alright so we will either be inserting or updating, but then how do I loop through the program when we insert by default. Can I select everything within users then go through them one by one.
#
# **The following query just dumps everything**
# ``` sql
# %%sql
# INSERT INTO users (user_id, first_name, last_name, gender, level)
# SELECT CAST(userId as INT), firstName, lastName, gender, level
#     FROM staging_events
#     WHERE userId != ' ';
# ```

# %%
# %%sql
# TRUNCATE users
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# Done.
# []

# %%
# %%sql
# SELECT DISTINCT(userId) as user_id, firstName, lastName, gender, level
#     FROM staging_events
#     WHERE userId != ' '
#     ORDER BY ts desc
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('12', 'Austin', 'Rosales', 'M', 'free'),
#  ('29', 'Jacqueline', 'Lynch', 'F', 'free'),
#  ('27', 'Carlos', 'Carter', 'M', 'free'),
#  ('25', 'Jayden', 'Graves', 'M', 'paid'),
#  ('81', 'Sienna', 'Colon', 'F', 'free')]

# %%
# %%sql
# INSERT INTO users (user_id, first_name, last_name, gender, level)
# SELECT DISTINCT(userId) as user_id, firstName, lastName, gender, level
#     FROM staging_events
#     WHERE userId != ' '
#     ORDER BY ts desc;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 29 rows affected.
# []

# %%
# %%sql
# SELECT COUNT(DISTINCT(user_id)) FROM users
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(29,)]

# %%
# %%sql
# SELECT COUNT((user_id)) FROM users
# LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(29,)]

# %% [markdown]
# ## Practice getting events into the songplays table
#
# * songplays not NULLs are
#   * start_time
#   * user_id
#   * session_id
#   * user_agent
# * Map staging_events into songplays
#   * ts -> start_time
#   * userId -> user_id
#   * level -> level
#   * **song_id TODO**
#   * **artist_id TODO**
#   * sessionId -> session_id
#   * location -> location
#   * userAgent -> user_agent

# %%
# %%sql
# SELECT date_add('ms',CAST(ts as BIGINT),'1970-01-01'), CAST(userId as INT), level, sessionId, staging_events.location, userAgent
#     FROM staging_events
#     WHERE userId != ' '
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), 69, 'free', 256, 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), 44, 'paid', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), 44, 'paid', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), 44, 'paid', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), 44, 'paid', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')]

# %%
# %%sql
# SELECT date_add('ms',CAST(ts as BIGINT),'1970-01-01'), CAST(userId as INT), level, s.song_id, sessionId, staging_events.location, userAgent
#     FROM staging_events
#     JOIN songs s      ON ('A Heart Without A Home'   = s.title)
#     WHERE userId != ' '
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), 69, 'free', 'SOJOVBQ12A6D4F96B6', 256, 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')]

# %%
# %%sql
# SELECT
#     date_add('ms',CAST(ts as BIGINT),'1970-01-01'),
#     CAST(userId as INT),
#     level,
#     (SELECT song_id FROM songs     WHERE songs.title   = 'A Heart Without A Home' LIMIT 1) as song_id,
#     (SELECT artist_id FROM artists WHERE artists.name  = 'The Hellacopters' LIMIT 1) as artist_id,
#     sessionId,
#     staging_events.location,
#     userAgent
#         FROM staging_events
#         WHERE userId != ' '
#         LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 5, 0, 33, 12, 796000), 69, 'free', 'SOJOVBQ12A6D4F96B6', 'ARSEMJF1187FB5641E', 256, 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 5, 1, 27, 22, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 'ARSEMJF1187FB5641E', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 30, 56, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 'ARSEMJF1187FB5641E', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 34, 54, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 'ARSEMJF1187FB5641E', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (datetime.datetime(2018, 11, 5, 1, 40, 40, 796000), 44, 'paid', 'SOJOVBQ12A6D4F96B6', 'ARSEMJF1187FB5641E', 237, 'Waterloo-Cedar Falls, IA', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0')]

# %%
# %%sql
# SELECT COUNT(*) FROM staging_events WHERE userId = ' ';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(7,)]

# %%
# %%sql
# INSERT INTO songplays ( start_time, user_id, level, song_id, artist_id, session_id, location, user_agent)
#     SELECT
#         date_add('ms',CAST(ts as BIGINT),'1970-01-01'),
#         CAST(userId as INT),
#         level,
#         (SELECT song_id FROM songs     WHERE songs.title   = 'A Heart Without A Home' LIMIT 1),
#         (SELECT artist_id FROM artists WHERE artists.name  = 'The Hellacopters' LIMIT 1),
#         sessionId,
#         staging_events.location,
#         userAgent
#             FROM staging_events
#             WHERE userId != ' ';
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 401 rows affected.
# []

# %%
# %%sql
# SELECT 'songplays' as title, COUNT(*) FROM songplays;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('songplays', 16342)]

# %%
# %%sql
# SELECT 'users'     as title, COUNT(DISTINCT(user_id)) FROM users;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('users', 97)]

# %%
# %%sql
# SELECT 'users'     as title, COUNT(*) FROM users;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('users', 105)]

# %%
# %%sql
# SELECT 'time'      as title, COUNT(*) FROM time;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('time', 8056)]

# %%
# %%sql
# SELECT 'time'      as title, COUNT(DISTINCT(start_time)) FROM time;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('time', 8023)]

# %%
# %%sql
# SELECT 'songs'     as title, COUNT(*) FROM songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# (psycopg2.ProgrammingError) column "start_time" does not exist in songs
#  [SQL: "SELECT 'songs'     as title, COUNT(DISTINCT(start_time)) FROM songs;"]

# %%
# %%sql
# SELECT 'artists'   as title, COUNT(*) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [('artists', 14896)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(artist_id)) FROM artists;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(9553,)]

# %%
# %%sql
# SELECT COUNT(DISTINCT(song_id)) FROM songs;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(14896,)]

# %%
# %%sql
# SELECT COUNT(*) FROM songs
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 1 rows affected.
# [(30356,)]

# %%
# %%sql
# SELECT song_id, title, a.artist_id, year, duration
#     FROM staging_songs s
#     JOIN artists a     ON (s.artist_name=a.name)
#     LIMIT 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('SODRVYY12A6D4FB2CE', "It's Funny_ I Don't Feel Like A Winner", 'AR73AIO1187B9AD57B', 2005, 81.42322),
#  ('SOGSOYU12A6D4FB2FB', 'Animals And Children', 'AR73AIO1187B9AD57B', 2005, 93.70077),
#  ('SOQPWCR12A6D4FB2A3', 'A Poor Recipe For Civic Cohesion', 'AR73AIO1187B9AD57B', 2005, 118.07302),
#  ('SOLLHMX12AB01846DC', 'The Emperor Falls', 'AR1Y2PT1187FB5B9CE', 0, 484.62322),
#  ('SOLUGTX12A6D4FAC08', 'So. Central Rain (2006 Digital Remaster)', 'ARR6LWJ1187FB44C8B', 0, 195.52608)]

# %%
# %%sql
# SELECT artist_id, COUNT(artist_id)
# FROM artists
# GROUP BY artist_id
# HAVING COUNT(artist_id)>1
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('ARA23XO1187B9AF18F', 4),
#  ('ARFCUN31187B9AD578', 4),
#  ('AR5LZJD1187FB4C5E5', 4),
#  ('ARGCVZG1187B9B916F', 3),
#  ('ARH5D6D1187FB4C572', 4)]

# %%
# %%sql
# SELECT song_id, COUNT(song_id)
# FROM songs
# GROUP BY song_id
# HAVING COUNT(song_id)>1
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('SOCSQHW12AB0181A51', 5),
#  ('SOHELLI12AB017C6D1', 4),
#  ('SODHXFY12A8C13418A', 2),
#  ('SOFVFEX12AB0188663', 3),
#  ('SOCPMTN12A8C137791', 2)]

# %%
# %%sql
# SELECT user_id, COUNT(user_id)
# FROM users
# GROUP BY user_id
# HAVING COUNT(user_id)>1
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [('80', 2), ('29', 2), ('85', 2), ('36', 2), ('15', 2)]

# %%
# %%sql
# SELECT start_time, COUNT(start_time)
# FROM time
# GROUP BY start_time
# HAVING COUNT(start_time)>1
# limit 5;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cexlscovpa8u.us-west-2.redshift.amazonaws.com:5439/dwh
# 5 rows affected.
# [(datetime.datetime(2018, 11, 14, 7, 32, 40, 796000), 2),
#  (datetime.datetime(2018, 11, 15, 18, 55, 4, 796000), 2),
#  (datetime.datetime(2018, 11, 4, 15, 25, 29, 796000), 2),
#  (datetime.datetime(2018, 11, 9, 18, 31, 5, 796000), 2),
#  (datetime.datetime(2018, 11, 12, 17, 7, 47, 796000), 2)]
